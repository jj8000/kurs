# %%
# !pip install numpy
# Out:
# ...
#      --------------------------------------- 14.6/14.6 MB 34.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %% [markdown]
# ## dfjsdf

# %%
a = np.array([[1, 2], [9, 8]])

# %%
a
# Out:
# array([[1, 2],
#        [9, 8]])

# %%
round(np.linalg.det(a), 5)
# Out:
# -10.0

# %%
# !pip install matplotlib
# !pip install pillow
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import PIL  
import urllib

# %%
kot = np.array(PIL.Image.open(urllib.request.urlopen("https://pngimg.com/uploads/pencil/pencil_PNG3853.png")))

# %%
kot.shape
# Out:
# (1720, 1720)

# %%
plt.imshow(kot)

# %%
plt.imshow(kot[500:1200, 1003:2500])
